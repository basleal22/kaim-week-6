# %%
import os
import pandas as pd
os.chdir('C:/Users/basleal/Desktop/tutorial/kaim-week-6')
print(os.getcwd())
# Out:
# C:\Users\basleal\Desktop\tutorial\kaim-week-6

# %%
# %load_ext autoreload
# %autoreload 2

# %%
path = 'C:/Users/basleal/Desktop/tutorial/kaim-week-6/data/data.csv'

# %%
data=pd.read_csv(path)

# %%
data.columns
# Out:
# Index(['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId',
#        'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductId',
#        'ProductCategory', 'ChannelId', 'Amount', 'Value',
#        'TransactionStartTime', 'PricingStrategy', 'FraudResult'],
#       dtype='object')

# %%
print(data.nunique())
# Out:
# TransactionId           95662
# BatchId                 94809
# AccountId                3633
# SubscriptionId           3627
# CustomerId               3742
# CurrencyCode                1
# CountryCode                 1
# ProviderId                  6
# ProductId                  23
# ProductCategory             9
# ChannelId                   4
# Amount                   1676
# Value                    1517
# TransactionStartTime    94556
# PricingStrategy             4
# FraudResult                 2
# dtype: int64

# %%
from scripts.feature_eng import num_aggregate
agg_num=num_aggregate(data)
agg_num
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 from scripts.feature_eng import num_aggregate
# ----> 2 agg_num=num_aggregate(data)
#       3 agg_num
#
# File ~\Desktop\tutorial\kaim-week-6\scripts\feature_eng.py:10, in num_aggregate(data)
#       8 def num_aggregate(data):
#       9     num_cols= ['Amount', 'Value', 'PricingStrategy', 'FraudResult','TransactionYear']
# ---> 10     num_agg= data.groupby('CustomerId')[num_cols].agg('mean','sum','max','min').reset_index()
#      11     return num_agg
#
# File c:\Users\basleal\Desktop\tutorial\kaim-week-6\venv\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# ...

# %%
from scripts.feature_eng import cat_aggregate
agg_cat=cat_aggregate(data)
agg_cat
# Out:
#                         TransactionId         BatchId       AccountId  \
# CustomerId
# CustomerId_1      TransactionId_51888   BatchId_22790  AccountId_1074
# CustomerId_10     TransactionId_24254    BatchId_4854  AccountId_1074
# CustomerId_1001   TransactionId_11879  BatchId_118083   AccountId_661
# CustomerId_1002  TransactionId_102164   BatchId_10941  AccountId_4841
# CustomerId_1003  TransactionId_124850  BatchId_121394   AccountId_663
# ...                               ...             ...             ...
# CustomerId_992   TransactionId_110861  BatchId_115940   AccountId_652
# CustomerId_993   TransactionId_107496  BatchId_102009   AccountId_653
# CustomerId_994   TransactionId_100294  BatchId_101233   AccountId_654
# CustomerId_996    TransactionId_10585   BatchId_28262   AccountId_656
# CustomerId_998    TransactionId_11160  BatchId_102067   AccountId_658
#
#                       SubscriptionId       CustomerId CurrencyCode  \
# CustomerId
# ...

# %%
from scripts.feature_eng import extract_date
data= extract_date(data)
data.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %%
'CurrencyCode', 'CountryCode', 'ProductCategory', 'ChannelId'

data.nunique()
# Out:
# TransactionId           95662
# BatchId                 94809
# AccountId                3633
# SubscriptionId           3627
# CustomerId               3742
# CurrencyCode                1
# CountryCode                 1
# ProviderId                  6
# ProductId                  23
# ProductCategory             9
# ChannelId                   4
# Amount                   1676
# Value                    1517
# TransactionStartTime    94556
# PricingStrategy             4
# FraudResult                 2
# TransactionHour            24
# TransactionDay             31
# TransactionMonth            4
# TransactionYear             2
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TransactionId         95662 non-null  object
#  1   BatchId               95662 non-null  object
#  2   AccountId             95662 non-null  object
#  3   SubscriptionId        95662 non-null  object
#  4   CustomerId            95662 non-null  object
#  5   CurrencyCode          95662 non-null  object
#  6   CountryCode           95662 non-null  int64
#  7   ProviderId            95662 non-null  object
#  8   ProductId             95662 non-null  object
#  9   ProductCategory       95662 non-null  object
#  10  ChannelId             95662 non-null  object
#  11  Amount                95662 non-null  float64
#  12  Value                 95662 non-null  int64
#  13  TransactionStartTime  95662 non-null  datetime64[ns, UTC]
# ...

# %%
from scripts.feature_eng import onehot_encoding
data=onehot_encoding(data)
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 from scripts.feature_eng import onehot_encoding
# ----> 2 data=onehot_encoding(data)
#       3 encoded_data
#
# File ~\Desktop\tutorial\kaim-week-6\scripts\feature_eng.py:29, in onehot_encoding(data)
#      26 def onehot_encoding(data):
#      27     # One-Hot Encoding
#      28     Labelencoder=LabelEncoder()
# ---> 29     data = pd.get_dummies(data, columns=['CurrencyCode', 'CountryCode', 'ProductCategory', 'ChannelId'],drop_first=True)
#      30      # Convert one-hot encoded columns to integers
#      31     for col in data.select_dtypes(include=['bool']).columns:
#
# File c:\Users\basleal\Desktop\tutorial\kaim-week-6\venv\Lib\site-packages\pandas\core\reshape\encoding.py:169, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
# ...

# %%
data.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId  ProviderId     ProductId   Amount  Value  \
# 0  CustomerId_4406           5  ProductId_10   1000.0   1000
# 1  CustomerId_4406           3   ProductId_6    -20.0     20
# 2  CustomerId_4683           5   ProductId_1    500.0    500
# 3   CustomerId_988           0  ProductId_21  20000.0  21800
# 4   CustomerId_988           3   ProductId_6   -644.0    644
#
#        TransactionStartTime  ...  ProductCategory_financial_services  \
# ...

# %%
from scripts.feature_eng import scaler
data=scaler(data)
data.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId  ProviderId     ProductId    Amount     Value  \
# 0  CustomerId_4406           5  ProductId_10  0.092004  0.000101
# 1  CustomerId_4406           3   ProductId_6  0.091910  0.000002
# 2  CustomerId_4683           5   ProductId_1  0.091958  0.000050
# 3   CustomerId_988           0  ProductId_21  0.093750  0.002206
# 4   CustomerId_988           3   ProductId_6  0.091853  0.000065
#
#        TransactionStartTime  ...  ProductCategory_financial_services  \
# ...

# %%
# saved our newly transformed data
data.to_csv('data_ready_train.csv')
